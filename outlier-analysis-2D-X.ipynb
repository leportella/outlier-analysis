# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random

from sklearn.preprocessing import LabelEncoder

# %matplotlib inline

# %% [markdown]
# # Gerando o dataframe

# %% [markdown]
# ## Gerando valores y

# %%
valores = np.random.wald(1000, 500, 1000)


plt.figure(figsize=(15,5))
plt.ylabel('Contagem dos valores')
plt.xlabel('Valores')
h = plt.hist(valores, bins=200)

# %%
df = pd.DataFrame()

# %%
df['y'] = valores

# %% [markdown]
# ## Gerando valores X

# %%
rng = np.random.RandomState(42)

# %%
Xs = 30 * rng.randn(df.shape[0], 2)

# %%
plt.scatter(Xs[:,0], Xs[:,1], c='black')
plt.ylabel('X2')
plt.xlabel('X1')
# Out:
# Text(0.5,0,'X1')

# %%
df['X1'] = X[:,0]
df['X2'] = X[:,1]

# %%
df.head()
# Out:
#             y         X1         X2
# 0  159.271072 -25.904808  -0.936105
# 1  316.291452   0.540506  14.178910
# 2  103.460694 -41.005751  17.777018
# 3  409.437670 -81.131749 -18.896537
# 4  361.552968 -14.648215  18.999805

# %%
df.describe()
# Out:
#                   y           X1           X2
# count   1000.000000  1000.000000  1000.000000
# mean     990.204024    -1.291637    -1.588700
# std     1309.629594    29.548994    30.438497
# min       48.522578   -90.228970   -95.301114
# 25%      260.583812   -20.650448   -20.551429
# 50%      495.791373    -1.569446    -0.411054
# 75%     1157.742112    19.121849    18.695019
# max    13991.544212    92.948983    93.387306

# %%
X = df[['X1', 'X2']]
y = df.y

# %% [markdown]
# # Análise de covariância com Elliptic Envelope considerando X e Y - 1%

# %%
from sklearn.covariance import EllipticEnvelope

clf = EllipticEnvelope(contamination=0.01)
clf.fit(X, y)
inliers = clf.predict(X)

# %%
plt.figure(figsize=(15,5))
plt.plot(y[inliers>0],'.')
plt.plot(y[inliers<0],'.')
plt.legend(['inliers', 'outliers'])
plt.title('EllipticEnvelope - 1%')
# Out:
# Text(0.5,1,'EllipticEnvelope - 1%')

# %%
plt.scatter(X['X1'][inliers>0], X['X2'][inliers>0], c='black')
plt.scatter(X['X1'][inliers<0], X['X2'][inliers<0], c='red')
plt.legend(['inliers', 'outliers'])

# %% [markdown]
# # Análise de covariância com Elliptic Envelope considerando X e Y - 10%

# %%
from sklearn.covariance import EllipticEnvelope

clf = EllipticEnvelope(contamination=0.1)
clf.fit(X, y)
inliers = clf.predict(X)

# %%
plt.figure(figsize=(15,5))
plt.plot(y[inliers>0],'.')
plt.plot(y[inliers<0],'.')
plt.legend(['inliers', 'outliers'])
plt.title('EllipticEnvelope - 10%')
# Out:
# Text(0.5,1,'EllipticEnvelope - 10%')

# %%
plt.scatter(X['X1'][inliers>0], X['X2'][inliers>0], c='black')
plt.scatter(X['X1'][inliers<0], X['X2'][inliers<0], c='red')
plt.legend(['inliers', 'outliers'])
plt.title('EllipticEnvelope - 10%')
# Out:
# Text(0.5,1,'EllipticEnvelope - 10%')

# %% [markdown]
# # Análise de covariância com Elliptic Envelope considerando Y - 1%

# %%
yy  = y.values.reshape(-1,1)

from sklearn.covariance import EllipticEnvelope

clf = EllipticEnvelope(contamination=0.01)

clf.fit(yy)
inliers = clf.predict(yy)

# %%
plt.figure(figsize=(15,5))
plt.plot(y[inliers>0],'.')
plt.plot(y[inliers<0],'.')
plt.legend(['inliers', 'outliers'])
plt.title('EllipticEnvelope - 1%')
# Out:
# Text(0.5,1,'EllipticEnvelope - 1%')

# %%
plt.scatter(X['X1'][inliers>0], X['X2'][inliers>0], c='black')
plt.scatter(X['X1'][inliers<0], X['X2'][inliers<0], c='red')
plt.legend(['inliers', 'outliers'])

# %% [markdown]
# # Análise de covariância com Elliptic Envelope considerando Y - 10%

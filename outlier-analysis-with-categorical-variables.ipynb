# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random

from sklearn.preprocessing import LabelEncoder

# %matplotlib inline

# %% [markdown]
# # Importing and visualizing my dataset

# %%
df = pd.read_csv('data/dataset.csv')

# %%
df.head()
# Out:
#    store_profit  products_in_stock  product_rating      business  \
# 0   4338.108328         109.934283       38.617357     souvenirs
# 1   1939.910530         112.953771       55.230299   supermarket
# 2    299.381392          95.316933       37.658630  construction
# 3    565.626098         131.584256       47.674347     souvenirs
# 4    365.750750          90.610512       45.425600          toys
#
#    number_of_stores  number_of_employees
# 0                 2                   80
# 1                 1                   15
# 2                 7                   81
# 3                 4                   15
# 4                11                    9

# %%
y = df.store_profit
X = df.drop('store_profit', axis=1)

# %% [markdown]
# # Categorical variables encoding

# %%
encoder = LabelEncoder()

# %%
for col in X.columns.values:
    X[col] = encoder.fit_transform(X[col])

# %% [markdown]
# # Elliptic Envelope analysis using X variables
#
# Using Ellipt Envelope considering a 1% contamination

# %%
from sklearn.covariance import EllipticEnvelope

clf = EllipticEnvelope(contamination=0.01)
clf.fit(X)
inliers = clf.predict(X)

# %%
plt.figure(figsize=(15,5))
plt.plot(y[inliers>0],'.')
plt.plot(y[inliers<0],'ro')
plt.legend(['inliers', 'outliers'])
plt.title('EllipticEnvelope - 1%')
# Out:
# Text(0.5,1,'EllipticEnvelope - 1%')

# %% [markdown]
# # Elliptic Envelope analysis using only Y
#
# Using Ellipt Envelope considering a 1% contamination and only our variable Y

# %%
yy  = y.values.reshape(-1,1)

from sklearn.covariance import EllipticEnvelope

clf = EllipticEnvelope(contamination=0.01)

clf.fit(yy)
inliers = clf.predict(yy)

# %%
min(y[inliers<0])
# Out:
# 7293.327862609279

# %%
plt.figure(figsize=(15,5))
plt.plot(y[inliers>0],'.')
plt.plot(y[inliers<0],'ro')
plt.plot(np.linspace(min(y[inliers<0]), min(y[inliers<0]), len(y)), 'k')
plt.legend(['inliers', 'outliers'])
plt.title('EllipticEnvelope - 1%')
# Out:
# Text(0.5,1,'EllipticEnvelope - 1%')
